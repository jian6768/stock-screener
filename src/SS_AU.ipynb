# %%
#Set up project root
project_root = sys.path.append(os.path.abspath(".."))

#import libraries
import yfinance as yf
import time
import pandas as pd
import random
from datetime import datetime
import os
import sys
from utils.file_utils import retrieve_single_company_info, date_today_string


#Dataframe with ticker, co_name, business_summary, industry/sector breakdown.. 
ticker_list_path = os.path.join("..","data","ticker_list",'ASX_tickers_final.csv')
ticker_list = pd.read_csv(ticker_list_path)

#Select the first 1666 tickers from ticker list
tickers = ticker_list['Ticker'][0:10]

#Process 20 tickers in each iteration. 
batch_size = 20

#for storing cross sectional stock data
# ticker_vals = {}
all_company_info = []

date_today = date_today_string()

#Loop through all tickers with step of batch size. 
for i in range(0, len(tickers), batch_size):
    #The last batch will have less than batch_size tickers.
    # Note python behavior: slicing a list by a number larger than the original list will not cause an out of index error. 
    # i.e.: if a list has 10 elements indexed 0-10, slicing it by ls[0:15] will return the 10 elements and not cause an error
    batch = tickers[i:i + batch_size]

    for ticker in batch:

        #fetches data for a particular ticker. Results are passed into different functions to avoid excessive number of API calls. 
        company = yf.Ticker(ticker)
        
        # Get company info
        retrieve_single_company_info(all_company_info, company, ticker)
      
        # Get financial statements
        income_statement = company.financials.T
        balance_sheet = company.balance_sheet.T
        cashflow_statement = company.cashflow.T

        # Display the data
        print("Income Statement:")
        print(income_statement)

        print("\nBalance Sheet:")
        print(balance_sheet)

        print("\nCash Flow Statement:")
        print(cashflow_statement)

        directory_date = f"../data/AU/financial_statements/{date_today}/"
        
        if not os.path.exists(directory_date):
            os.makedirs(directory_date)
            print(f"Directory '{directory_date}' created.")
        else:
            print(f"Directory '{directory_date}' already exists.")
        
        
        financial_statements_dir = os.path.join("..", "data", "AU", "financial_statements", date_today)

        # Save the data in csv files for future reference. Rewrite code to store in database in future. 
        csv_filename_IS = os.path.join(financial_statements_dir, f"{ticker}_IS.csv")
        income_statement.to_csv(csv_filename_IS)
        csv_filename_BS = os.path.join(financial_statements_dir, f"{ticker}_BS.csv")
        balance_sheet.to_csv(csv_filename_BS)
        csv_filename_CF = os.path.join(financial_statements_dir, f"{ticker}_CF.csv")
        cashflow_statement.to_csv(csv_filename_CF)

        print(f"Saved data")   

    time.sleep(10+random.random()*2)
# Out:
# Income Statement:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Total Unusual Items  \
# 2024-06-30                -137904000.0              0.312        -442000000.0
# 2023-06-30                  17751000.0              0.291          61000000.0
# 2022-06-30                 122010000.0              0.294         415000000.0
# 2021-06-30            -71638949.494949           0.285414        -251000000.0
# 2020-06-30                         NaN                NaN                 NaN
#
#            Total Unusual Items Excluding Goodwill  \
# 2024-06-30                           -442000000.0
# 2023-06-30                             61000000.0
# 2022-06-30                            415000000.0
# 2021-06-30                           -251000000.0
# 2020-06-30                                    NaN
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 
# 2024-06-30               1307000000.0           485000000.0    629000000.0
# 2023-06-30               1507000000.0           480000000.0    545000000.0
# 2022-06-30               1490000000.0           481000000.0    490000000.0
# 2021-06-30               1522000000.0           491000000.0    465000000.0
# 2020-06-30                        NaN                   NaN            NaN
#
#              Receivables Taxes Receivable Other Short Term Investments  \
# 2024-06-30  5056000000.0       21000000.0                          NaN
# 2023-06-30  4401000000.0        8000000.0                          NaN
# 2022-06-30  2481000000.0        7000000.0                          NaN
# 2021-06-30  2562000000.0      123000000.0                          NaN
# 2020-06-30           NaN              NaN                22031000000.0
#
#            Cash And Cash Equivalents  Cash Financial  \
# 2024-06-30             48110000000.0   47321000000.0
# 2023-06-30            108008000000.0  107172000000.0
# 2022-06-30            120315000000.0  119355000000.0
# 2021-06-30             88524000000.0   87375000000.0
# 2020-06-30                       NaN             NaN
#
#            Cash Cash Equivalents And Federal Funds Sold
# 2024-06-30                               129938000000.0
# 2023-06-30                               156454000000.0
# 2022-06-30                               162114000000.0
# 2021-06-30                               101190000000.0
# 2020-06-30                                          NaN
#
# [5 rows x 68 columns]
#
# Cash Flow Statement:
#            Free Cash Flow Repurchase Of Capital Stock Repayment Of Debt  \
# 2024-06-30 -26945000000.0                -362000000.0    -82457000000.0
# 2023-06-30  -9958000000.0               -2634000000.0    -52970000000.0
# 2022-06-30  22263000000.0               -6547000000.0    -52419000000.0
# 2021-06-30  40545000000.0                 -71000000.0    -52166000000.0
# 2020-06-30            NaN                         NaN               NaN
#
#            Issuance Of Debt Issuance Of Capital Stock Capital Expenditure  \
# 2024-06-30    57610000000.0                       0.0       -1322000000.0
# 2023-06-30    59498000000.0                       0.0       -1568000000.0
# 2022-06-30    71687000000.0                48000000.0        -977000000.0
# 2021-06-30    74950000000.0                 5000000.0        -767000000.0
# 2020-06-30              NaN                       NaN                 NaN
#
#            Interest Paid Supplemental Data Income Tax Paid Supplemental Data  \
# 2024-06-30                             NaN                               NaN
# 2023-06-30                             NaN                               NaN
# 2022-06-30                             NaN                               NaN
# 2021-06-30                             NaN                               NaN
# 2020-06-30                   11932000000.0                      3171000000.0
#
#            End Cash Position Beginning Cash Position  ...  Depreciation  \
# 2024-06-30     47321000000.0          107172000000.0  ...           NaN
# 2023-06-30    107172000000.0          119355000000.0  ...  1110000000.0
# 2022-06-30    119355000000.0           87380000000.0  ...  1518000000.0
# 2021-06-30     87380000000.0           27351000000.0  ...  1426000000.0
# 2020-06-30               NaN                     NaN  ...           NaN
#
#            Gain Loss On Investment Securities Gain Loss On Sale Of PPE  \
# 2024-06-30                                NaN                      NaN
# 2023-06-30                         -1000000.0                4000000.0
# 2022-06-30                         -4000000.0              -12000000.0
# 2021-06-30                        -39000000.0                4000000.0
# 2020-06-30                                NaN                      NaN
#
#            Gain Loss On Sale Of Business  \
# 2024-06-30                           NaN
# 2023-06-30                  -291000000.0
# 2022-06-30                 -2079000000.0
# 2021-06-30                  -840000000.0
# 2020-06-30                           NaN
#
#            Net Income From Continuing Operations  \
# 2020-06-30                          NaN                       NaN
#
#            Cash Equivalents Cash Financial
# 2024-06-30              NaN            NaN
# 2023-06-30     5222000000.0   7206000000.0
# 2022-06-30    11508000000.0   5728000000.0
# 2021-06-30    10838000000.0   4408000000.0
# 2020-06-30     9933000000.0   3493000000.0
#
# [5 rows x 91 columns]
#
# Cash Flow Statement:
#            Free Cash Flow Repurchase Of Capital Stock Repayment Of Debt  \
# 2024-06-30  11849000000.0                         NaN     -7327000000.0
# 2023-06-30  11968000000.0                         NaN     -3289000000.0
# 2022-06-30  26319000000.0                         NaN     -3358000000.0
# 2021-06-30  21622000000.0                         0.0     -8357000000.0
# 2020-06-30            NaN                         0.0               NaN
#
#            Issuance Of Debt Capital Expenditure End Cash Position  \
# 2024-06-30     5091000000.0       -8816000000.0     12498000000.0
# 2023-06-30     8182000000.0       -6733000000.0     12423000000.0
# 2022-06-30     1164000000.0       -5855000000.0     17236000000.0
# 2021-06-30      568000000.0       -5612000000.0     15246000000.0
# 2020-06-30              NaN                 NaN               NaN
#
#            Beginning Cash Position Effect Of Exchange Rate Changes  \
# 2024-06-30           12423000000.0                    -159000000.0
# 2023-06-30           17236000000.0                    -134000000.0
# 2022-06-30           15246000000.0                    -458000000.0
# 2021-06-30           13426000000.0                     353000000.0
# 2020-06-30                     NaN                             NaN
#
#            Changes In Cash Financing Cash Flow  ...  \
# 2024-06-30     234000000.0      -11669000000.0  ...
# 2023-06-30   -4679000000.0      -10315000000.0  ...
# 2022-06-30    2448000000.0      -22767000000.0  ...
# 2021-06-30    1467000000.0      -17922000000.0  ...
# 2020-06-30             NaN                 NaN  ...
#
#            Depreciation Amortization Depletion Depreciation And Amortization  \
# 2024-06-30                        5295000000.0                  5295000000.0
# 2023-06-30                        5061000000.0                  5061000000.0
# 2022-06-30                        5683000000.0                  5683000000.0
# 2021-06-30                        5084000000.0                  5084000000.0
# 2020-06-30                                 NaN                           NaN
#
#            Amortization Cash Flow Amortization Of Intangibles  Depreciation  \
# 2024-06-30            107000000.0                 107000000.0  5188000000.0
# 2023-06-30             94000000.0                  94000000.0  4967000000.0
# 2022-06-30                    NaN                         NaN           NaN
# 2021-06-30                    NaN                         NaN           NaN
# 2020-06-30                    NaN                         NaN           NaN
#
#            Operating Gains Losses Earnings Losses From Equity Investments  \
# 2024-06-30           2657000000.0                            2656000000.0
# 2023-06-30           -697000000.0                            -594000000.0
# 2022-06-30            -89000000.0                              19000000.0
# 2021-06-30           1334000000.0                             915000000.0
# 2020-06-30                    NaN                                     NaN
#
#            Gain Loss On Investment Securities  \
# 2024-06-30                        -26000000.0
# 2023-06-30                       -112000000.0
# 2022-06-30                         -9000000.0
# 2021-06-30                        -75000000.0
# 2020-06-30                                NaN
#
#            Net Foreign Currency Exchange Gain Loss  \
# 2024-06-30                              27000000.0
# 2023-06-30                               9000000.0
# 2022-06-30                             -99000000.0
# 2021-06-30                              99000000.0
# 2020-06-30                                     NaN
#
#            Net Income From Continuing Operations
# 2024-06-30                         16048000000.0
# 2023-06-30                         21401000000.0
# 2022-06-30                         33137000000.0
# 2021-06-30                         24292000000.0
# 2020-06-30                                   NaN
#
# [5 rows x 59 columns]
# Directory '../data/AU/financial_statements/20250412/' already exists.
# Saved data
# Income Statement:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Normalized EBITDA  \
# 
#                     EBIT Net Interest Income Interest Expense  ...  \
# 2024-06-30  3795000000.0        -437000000.0      420000000.0  ...
# 2023-06-30  3071000000.0        -406000000.0      408000000.0  ...
# 2022-06-30  2922400000.0        -160600000.0      142800000.0  ...
# 2021-06-30  3133900000.0        -166900000.0      170800000.0  ...
# 2020-06-30           NaN                 NaN              NaN  ...
#
#            Depreciation Income Statement Research And Development  \
# 2024-06-30                   528000000.0             1430000000.0
# 2023-06-30                   490000000.0             1235000000.0
# 2022-06-30                   445700000.0             1156200000.0
# 2021-06-30                   399400000.0             1001400000.0
# 2020-06-30                           NaN                      NaN
#
#            Selling General And Administration Selling And Marketing Expense  \
# 2024-06-30                       2429000000.0                  1573000000.0
# 2023-06-30                       2540000000.0                  1454000000.0
# 2022-06-30                       1648700000.0                   960700000.0
# 2021-06-30                       1711900000.0                   980200000.0
# 2020-06-30                                NaN                           NaN
#
#            General And Administrative Expense  Other Gand A  Gross Profit  \
# 2024-06-30                        856000000.0   856000000.0  7561000000.0
# 2023-06-30                       1086000000.0  1086000000.0  6708000000.0
# 2022-06-30                        688000000.0   688000000.0  5663500000.0
# 2021-06-30                        731700000.0   731700000.0  5798600000.0
# 2020-06-30                                NaN           NaN           NaN
#
#            Cost Of Revenue  Total Revenue Operating Revenue
# 2024-06-30    7129000000.0  14690000000.0     14690000000.0
# 2023-06-30    6466000000.0  13174000000.0     13174000000.0
# 2022-06-30    4829600000.0  10493100000.0     10493100000.0
# 2021-06-30    4466700000.0  10265300000.0     10265300000.0
# 2020-06-30             NaN            NaN               NaN
#
# [5 rows x 47 columns]
#
# Balance Sheet:
#            Ordinary Shares Number Share Issued      Net Debt     Total Debt  \
# 2024-06-30            483252729.0  483252729.0  8862000000.0  12183000000.0
# 2023-06-30            482369261.0  482369261.0  8980000000.0  12227000000.0
# 2022-06-30            481706266.0  481706266.0           NaN   9657800000.0
# 2021-06-30            455125994.0  455125994.0  2815700000.0   5806900000.0
# 2020-06-30                    NaN          NaN  4713000000.0            NaN
#
#            Tangible Book Value    Invested Capital  Working Capital  \
# 2024-06-30        1017000000.0       27882000000.0  5817999999.9999
# 2023-06-30        -660000000.0       26314000000.0     4651000000.0
# 2022-06-30  11939400000.000099  22860500000.000099     9352500000.0
# 2021-06-30        5711600000.0       13005800000.0     4286100000.0
# 2020-06-30                 NaN                 NaN              NaN
#
#            Net Tangible Assets Capital Lease Obligations Common Stock Equity  \
# 2024-06-30        1017000000.0              1664000000.0       17363000000.0
# 2023-06-30        -660000000.0              1699000000.0       15786000000.0
# 2022-06-30  11939400000.000099              1374800000.0  14577500000.000099
# 2021-06-30        5711600000.0              1182400000.0        8381300000.0
# 2020-06-30                 NaN                       NaN                 NaN
#
#             ... Raw Materials   Receivables  \
# 2024-06-30  ...  1785000000.0  2641000000.0
# 2023-06-30  ...  1592000000.0  1905000000.0
# 2022-06-30  ...  1515200000.0  1483200000.0
# 2021-06-30  ...  1309100000.0  1563700000.0
# 2020-06-30  ...           NaN           NaN
#
#            Receivables Adjustments Allowances Other Receivables  \
# 2024-06-30                        -16000000.0       571000000.0
# 2023-06-30                        -12000000.0       493000000.0
# 2022-06-30                        -16900000.0       534300000.0
# 2021-06-30                        -23500000.0       590200000.0
# 2020-06-30                                NaN               NaN
#
#            Accounts Receivable  \
# 2024-06-30        2086000000.0
# 2023-06-30        1424000000.0
# 2022-06-30         965800000.0
# 2021-06-30         997000000.0
# 2020-06-30                 NaN
#
#            Cash Cash Equivalents And Short Term Investments  \
# 2024-06-30                                     1657000000.0
# 2023-06-30                                     1548000000.0
# 2022-06-30                                    10436400000.0
# 2021-06-30                                     1808800000.0
# 2020-06-30                                              NaN
#
#            Other Short Term Investments Cash And Cash Equivalents  \
# 2024-06-30                          NaN              1657000000.0
# 2023-06-30                          NaN              1548000000.0
# 2022-06-30                          NaN             10436400000.0
# 2021-06-30                    4800000.0              1808800000.0
# 2020-06-30                    3300000.0                       NaN
#
#            Cash Equivalents Cash Financial
# 2024-06-30      772000000.0    885000000.0
# 2023-06-30      552000000.0    996000000.0
# 2022-06-30     8905400000.0   1531000000.0
# 2021-06-30      382800000.0   1426000000.0
# 2020-06-30              NaN            NaN
#
# [5 rows x 86 columns]
#
# Cash Flow Statement:
#            Free Cash Flow Repayment Of Debt Issuance Of Debt  \
# 2024-06-30   1506000000.0     -2017000000.0     2058000000.0
# 2023-06-30    909000000.0      -798000000.0     2539000000.0
# 2022-06-30   1381000000.0      -316400000.0     4092700000.0
# 2021-06-30   1954800000.0      -470900000.0       38700000.0
# 2020-06-30            NaN               NaN              NaN
#
#            Issuance Of Capital Stock Capital Expenditure  \
# 2024-06-30                40000000.0       -1258000000.0
# 2023-06-30                34000000.0       -1692000000.0
# 2022-06-30              4988400000.0       -1247700000.0
# 2021-06-30                56400000.0       -1667100000.0
# 2020-06-30                       NaN                 NaN
#
#            Interest Paid Supplemental Data Income Tax Paid Supplemental Data  \
# 2024-06-30                     432000000.0                       784000000.0
# 2023-06-30                     374000000.0                       563000000.0
# 2022-06-30                     172300000.0                       457100000.0
# 2021-06-30                     160900000.0                       494500000.0
# 2020-06-30                             NaN                               NaN
#
#            End Cash Position Beginning Cash Position  \
# 2024-06-30      1643000000.0            1509000000.0
# 2023-06-30      1509000000.0           10334000000.0
# 2022-06-30     10334400000.0            1730100000.0
# 2021-06-30      1730100000.0            1151300000.0
# 2020-06-30               NaN                     NaN
#
#            Effect Of Exchange Rate Changes  ...  \
# 2024-06-30                     -87000000.0  ...
# 2023-06-30                     -39000000.0  ...
# 2022-06-30                     -64200000.0  ...
# 2021-06-30                      31900000.0  ...
# 2020-06-30                             NaN  ...
#
#            Net Intangibles Purchase And Sale Purchase Of Intangibles  \
# 2024-06-30                      -409000000.0            -409000000.0
# 2023-06-30                      -464000000.0            -464000000.0
# 2022-06-30                      -168900000.0            -168900000.0
# 2021-06-30                      -470800000.0            -470800000.0
# 2020-06-30                               NaN                     NaN
#
#            Net PPE Purchase And Sale  Sale Of PPE Purchase Of PPE  \
# 2024-06-30              -847000000.0    2000000.0    -849000000.0
# 2023-06-30             -1117000000.0  111000000.0   -1228000000.0
# 2022-06-30             -1078800000.0          NaN   -1078800000.0
# 2021-06-30             -1196300000.0          NaN   -1196300000.0
# 2020-06-30                       NaN          NaN             NaN
#
#            Cash Flowsfromusedin Operating Activities Direct  \
# 2024-06-30                                     2764000000.0
# 2023-06-30                                     2601000000.0
# 2022-06-30                                     2628700000.0
# 2021-06-30                                     3621900000.0
# 2020-06-30                                              NaN
#
#            Taxes Refund Paid Direct Interest Paid Direct  \
# 2024-06-30             -784000000.0         -432000000.0
# 2023-06-30             -563000000.0         -374000000.0
# 2022-06-30             -457100000.0         -172300000.0
# 2021-06-30             -494500000.0         -160900000.0
# 2020-06-30                      NaN                  NaN
#
#            Classesof Cash Receiptsfrom Operating Activities  \
# 2024-06-30                                     3980000000.0
# 2023-06-30                                     3538000000.0
# 2022-06-30                                     3258100000.0
# 2021-06-30                                     4277300000.0
# 2020-06-30                                              NaN
#
#            Other Cash Receiptsfrom Operating Activities
# 2024-06-30                                 3980000000.0
# 2023-06-30                                 3538000000.0
# 2022-06-30                                 3258100000.0
# 2021-06-30                                 4277300000.0
# 2020-06-30                                          NaN
#
# [5 rows x 40 columns]
# Directory '../data/AU/financial_statements/20250412/' already exists.
# Saved data
# Income Statement:
#            Tax Effect Of Unusual Items Tax Rate For Calcs Total Unusual Items  \
# 2024-09-30             -2265816.378176           0.283227          -8000000.0
# 2023-09-30             -3136842.105263           0.285167         -11000000.0
# 2022-09-30             51509441.707718           0.275452         187000000.0
# 2021-09-30              -4582267.31363           0.286392         -16000000.0
# 2020-09-30                         NaN                NaN                 NaN
#
#            Total Unusual Items Excluding Goodwill  \
# 2024-09-30                             -8000000.0
# 2023-09-30                            -11000000.0
# 2022-09-30                            187000000.0
# 2021-09-30                            -16000000.0
# 2020-09-30                                    NaN
#
#            Net Income From Continuing Operation Net Minority Interest  \
# 2024-09-30                                       7063000000.0
# 2023-09-30                                       7465000000.0
# 2022-09-30                                       7060000000.0
# 2021-09-30                                       6468000000.0
# 2020-09-30                                                NaN
#
#            Reconciled Depreciation Net Interest Income Interest Expense  \
# 2024-09-30            1312000000.0       16757000000.0    41540000000.0
# 2023-09-30            1216000000.0       16807000000.0    31265000000.0
# 2022-09-30            1112000000.0       14840000000.0     7538000000.0
# 2021-09-30            1045000000.0       13793000000.0     4241000000.0
# 2020-09-30                     NaN                 NaN              NaN
#
#            Interest Income  Normalized Income  ...  \
# 2024-09-30   58297000000.0  7068734183.621824  ...
# 2023-09-30   48072000000.0  7472863157.894737  ...
# 2022-09-30   22378000000.0  6924509441.707718  ...
# 2021-09-30   18034000000.0   6479417732.68637  ...
# 2020-09-30             NaN                NaN  ...
#
#            Selling General And Administration Selling And Marketing Expense  \
# 2024-09-30                       1467000000.0                   209000000.0
# 2023-09-30                       1417000000.0                   220000000.0
# 2022-09-30                       2414000000.0                   187000000.0
# 2021-09-30                       2044000000.0                   160000000.0
# 2020-09-30                                NaN                           NaN
#
# ...
# 2021-03-31                  279000000.0            NaN   5284000000.0
#
#            Other Receivables Accounts Receivable  \
#
# [5 rows x 55 columns]
#
# Balance Sheet:
#            Ordinary Shares Number  Share Issued      Net Debt     Total Debt  \
# 2024-06-30           1134781000.0  1134781000.0  3921000000.0  11278000000.0
# 2023-06-30           1134514000.0  1134514000.0  3757000000.0  11169000000.0
# 2022-06-30           1134145000.0  1134145000.0  4253000000.0  12081000000.0
# 2021-06-30           1133840000.0  1133840000.0           NaN  10127000000.0
# 2020-06-30                    NaN           NaN           NaN            NaN
#
#            Tangible Book Value Invested Capital Working Capital  \
# 2024-06-30        3534000000.0    13341000000.0    1186000000.0
# 2023-06-30        3589000000.0    12711000000.0    1297000000.0
# 2022-06-30        3330000000.0    12939000000.0     712000000.0
# 2021-06-30        5812000000.0    12737000000.0    1181000000.0
# 2020-06-30                 NaN              NaN             NaN
#
#            Net Tangible Assets Capital Lease Obligations Common Stock Equity  \
# 2024-06-30        3534000000.0              6522000000.0        8585000000.0
# 2023-06-30        3589000000.0              6739000000.0        8281000000.0
# 2022-06-30        3330000000.0              7123000000.0        7981000000.0
# 2021-06-30        5812000000.0              7105000000.0        9715000000.0
# 2020-06-30                 NaN                       NaN                 NaN
#
#             ... Finished Goods Raw Materials   Receivables  \
# 2024-06-30  ...   6038000000.0    57000000.0  2210000000.0
# 2023-06-30  ...   5997000000.0    34000000.0  2046000000.0
# 2022-06-30  ...   6047000000.0    28000000.0  2094000000.0
# 2021-06-30  ...   4465000000.0    28000000.0  1247000000.0
# 2020-06-30  ...            NaN           NaN           NaN
#
#            Receivables Adjustments Allowances Other Receivables  \
# 2024-06-30                        -60000000.0       215000000.0
# 2023-06-30                        -63000000.0       217000000.0
# 2022-06-30                        -55000000.0       211000000.0
# 2021-06-30                        -33000000.0       210000000.0
# 2020-06-30                                NaN               NaN
#
#            Accounts Receivable  \
# 2024-06-30        2055000000.0
# 2023-06-30        1892000000.0
# 2022-06-30        1938000000.0
# 2021-06-30        1070000000.0
# 2020-06-30                 NaN
#
#            Cash Cash Equivalents And Short Term Investments  \
# 2024-06-30                                      835000000.0
# 2023-06-30                                      673000000.0
# 2022-06-30                                      705000000.0
# 2021-06-30                                     3023000000.0
# 2020-06-30                                              NaN
#
#            Cash And Cash Equivalents Cash Equivalents Cash Financial
# 2024-06-30               835000000.0      484000000.0    351000000.0
# 2023-06-30               673000000.0      421000000.0    252000000.0
# 2022-06-30               705000000.0      467000000.0    238000000.0
# 2021-06-30              3023000000.0     2795000000.0    228000000.0
# 2020-06-30                       NaN              NaN            NaN
#
# [5 rows x 79 columns]
#
# Cash Flow Statement:
#            Free Cash Flow Repayment Of Debt Issuance Of Debt  \
# 2024-06-30   3518000000.0       -30000000.0      347000000.0
# 2023-06-30   2891000000.0      -765000000.0      380000000.0
# 2022-06-30   1157000000.0     -1166000000.0     2961000000.0
# 2021-06-30   2487000000.0      -571000000.0     1000000000.0
# 2020-06-30            NaN               NaN              NaN
#
#            Capital Expenditure Interest Paid Supplemental Data  \
# 2024-06-30       -1076000000.0                     388000000.0
# 2023-06-30       -1288000000.0                     359000000.0
# 2022-06-30       -1144000000.0                     309000000.0
# 2021-06-30        -896000000.0                     335000000.0
# 2020-06-30                 NaN                             NaN
#
#            Income Tax Paid Supplemental Data End Cash Position  \
# 2024-06-30                       856000000.0       835000000.0
# 2023-06-30                      1120000000.0       673000000.0
# 2022-06-30                      1300000000.0       705000000.0
# 2021-06-30                      1015000000.0      3023000000.0
# 2020-06-30                               NaN               NaN
#
#            Beginning Cash Position Changes In Cash Financing Cash Flow  ...  \
# 2024-06-30             673000000.0     162000000.0       -3063000000.0  ...
# 2023-06-30             705000000.0     -32000000.0       -3659000000.0  ...
# 2022-06-30            3023000000.0   -2318000000.0       -3428000000.0  ...
# 2021-06-30            2913000000.0     110000000.0       -2631000000.0  ...
# 2020-06-30                     NaN             NaN                 NaN  ...
#
#            Purchase Of PPE Cash Flowsfromusedin Operating Activities Direct  \
# 2024-06-30   -1076000000.0                                     4594000000.0
# 2023-06-30   -1288000000.0                                     4179000000.0
# 2022-06-30   -1144000000.0                                     2301000000.0
# 2021-06-30    -896000000.0                                     3383000000.0
# 2020-06-30             NaN                                              NaN
#
#            Taxes Refund Paid Direct Interest Received Direct  \
# 2024-06-30             -856000000.0               28000000.0
# 2023-06-30            -1120000000.0               16000000.0
# 2022-06-30            -1300000000.0                5000000.0
# 2021-06-30            -1015000000.0               12000000.0
# 2020-06-30                      NaN                      NaN
#
#            Interest Paid Direct Dividends Received Direct  \
# 2024-06-30         -388000000.0                81000000.0
# 2023-06-30         -359000000.0                73000000.0
# 2022-06-30         -309000000.0               102000000.0
# 2021-06-30         -335000000.0                91000000.0
# 2020-06-30                  NaN                       NaN
#
#            Classesof Cash Payments Paymentsto Suppliersfor Goodsand Services  \
# 2024-06-30          -43039000000.0                            -43039000000.0
# 2023-06-30          -42684000000.0                            -42684000000.0
# 2022-06-30          -36754000000.0                            -36754000000.0
# 2021-06-30          -32773000000.0                            -32773000000.0
# 2020-06-30                     NaN                                       NaN
#
#            Classesof Cash Receiptsfrom Operating Activities  \
# 2024-06-30                                    48768000000.0
# 2023-06-30                                    48253000000.0
# 2022-06-30                                    40557000000.0
# 2021-06-30                                    37403000000.0
# 2020-06-30                                              NaN
#
#            Receiptsfrom Customers
# 2024-06-30          48768000000.0
# 2023-06-30          48253000000.0
# 2022-06-30          40557000000.0
# 2021-06-30          37403000000.0
# 2020-06-30                    NaN
#
# [5 rows x 38 columns]
# Directory '../data/AU/financial_statements/20250412/' already exists.
# Saved data

# %%
new_df = pd.DataFrame.from_dict(all_company_info)
new_df.set_index('ticker', inplace=True)
new_df = new_df.reset_index()
company_info = os.path.join("..", "data", "AU", "company_info","company_info.csv")
new_df.to_csv(company_info)

# %% [markdown]
# #Load Data using CSVs (Income statements, Balance sheets and CF statements) that have been downloaded previously.

# %%
#Memory efficient implementation of load data frames
""" 
    Takes in tickers as inputs, gradually yields dataframes. 
    Concat all data frames using lazy loading. 
"""

#Set up project root
project_root = sys.path.append(os.path.abspath(".."))

#takes in tickers as inputs, gradually passes data frames. 
#uses a generator ins
import pandas as pd
import numpy as np
import os
from utils.file_utils import load_fin_data_yield, date_today_string
from utils.financial_formula_utils import create_prior_year_BS_item, compute_prior_year_BS_item_and_average, compute_rate_of_change, compute_ratio, add_rate_of_change_to_df, add_financial_ratio_to_df, retrieve_metric_3Y_time_series, retrieve_metrics_3Y_time_series
from src.constants import roc_is_metrics, roc_bs_metrics, financial_ratio_tuples

ticker_list_path = os.path.join("..","data","ticker_list",'ASX_tickers_final.csv')
ticker_list = pd.read_csv(ticker_list_path)[:1666]

tickers = ticker_list['Ticker']

directory_statements = os.path.join("..", "data", "AU", "financial_statements")


# date_today = date_today_string()
date_today = "20250312"

df_IS = pd.concat(load_fin_data_yield(tickers, "IS",date_today,directory_statements), axis=0)
df_BS = pd.concat(load_fin_data_yield(tickers, "BS",date_today,directory_statements), axis=0)
df_CF = pd.concat(load_fin_data_yield(tickers, "CF",date_today,directory_statements), axis=0)

# %%
#Merges Income Statement, Balance Sheet and Company Information
is_bs_co_df = df_IS.merge(df_BS, on=['ticker','FY_End'], how='outer')
is_bs_co_df = is_bs_co_df.sort_values(by = ['ticker','FY_End'])
is_bs_co_df = is_bs_co_df.merge(ticker_list,left_on='ticker', right_on="Ticker",how='inner')

#Create a new column FY based on FY_End date
is_bs_co_df["FY"] = is_bs_co_df["FY_End"].apply(lambda x:(x[:4]))

print(df_IS.shape)
print(df_BS.shape)
print(ticker_list.shape)
print(is_bs_co_df.shape)
# Out:
# (7153, 82)
# (7282, 139)
# (1666, 9)
# (7368, 229)

# %%
roc_metrics = roc_is_metrics + roc_bs_metrics

is_bs_co_df = add_rate_of_change_to_df(is_bs_co_df, roc_metrics)
is_bs_co_df = add_financial_ratio_to_df(is_bs_co_df, financial_ratio_tuples)
is_bs_co_df
# Out:
#       ticker      FY_End  Tax Effect Of Unusual Items  Tax Rate For Calcs  \
# 0     14D.AX  2020-06-30                          NaN                 NaN
# 1     14D.AX  2021-06-30                     0.000000            0.000000
# 2     14D.AX  2022-06-30                     0.000000            0.000000
# 3     14D.AX  2023-06-30                     0.000000            0.000000
# 4     14D.AX  2024-06-30                     0.000000            0.000000
# ...      ...         ...                          ...                 ...
# 7363  ZNO.AX  2020-06-30                          NaN                 NaN
# 7364  ZNO.AX  2021-06-30                     0.000000            0.214433
# 7365  ZNO.AX  2022-06-30               -280545.725943            0.048651
# 7366  ZNO.AX  2023-06-30                     0.000000            0.280000
# 7367  ZNO.AX  2024-06-30                     0.000000            0.000000
#
#       Total Unusual Items  Total Unusual Items Excluding Goodwill  \
# 0                     NaN                                     NaN
# 1           -2.933040e+06                           -2.933040e+06
# 2           -9.975160e+05                           -9.975160e+05
# 3                     NaN                                     NaN
# 4            6.982000e+03                            6.982000e+03
# ...                   ...                                     ...
# 7363                  NaN                                     NaN
# 7364                  NaN                                     NaN
# 7365        -5.766470e+06                           -5.766470e+06
# 7366                  NaN                                     NaN
# 7367        -4.624785e+06                           -4.624785e+06
#
#       Net Income From Continuing Operation Net Minority Interest  \
# 0                                                   NaN
# 1                                         -5.974178e+06
# 2                                         -1.369310e+06
# 3                                         -1.831251e+06
# 4                                         -2.505500e+06
# ...                                                 ...
# 7363                                                NaN
# 7364                                       4.404346e+06
# 7365                                      -1.027659e+07
# 7366                                      -3.219682e+05
# 7367                                      -8.317346e+06
#
#       Reconciled Depreciation  Net Interest Income  Interest Expense  ...  \
# 0                         NaN                  NaN               NaN  ...
# 1                 136772.0000          -85421.0000       104249.0000  ...
# 2                 380879.0000         -257996.0000       276997.0000  ...
# 3                  30200.0000           28268.0000         1022.0000  ...
# 4                  35242.0000          -10703.0000        40529.0000  ...
# ...                       ...                  ...               ...  ...
# 7363                      NaN                  NaN               NaN  ...
# 7364              334880.4094          -53272.2196        70005.5840  ...
# 7365              279605.8802          -62794.9134         1617.0635  ...
# 7366              394694.4776          -53960.3051        58503.1701  ...
# 7367              357723.0713          -67531.8020        71521.9182  ...
#
#           ROIC  Net Income Margin  Operating Profit Margin  EBITDA Margin  \
# 0          NaN                NaN                      NaN            NaN
# 1          NaN                NaN                      NaN            NaN
# 2    -0.124460          -3.502887                -9.117608      -1.819948
# 3    -0.189670                NaN                      NaN            NaN
# 4    -0.306851                NaN                      NaN            NaN
# ...        ...                ...                      ...            ...
# 7363       NaN                NaN                      NaN            NaN
# 7364       NaN           0.174414                 0.210121       0.233401
# 7365 -0.692276          -1.263958                -0.714236      -1.374669
# 7366 -0.031980          -0.105017                -1.755634      -0.059240
# 7367 -1.014466          -8.661186                -3.871241      -8.214196
#
#       EBIT Margin  Gross Profit Margin  Average Interest Rate  \
# 0             NaN                  NaN                    NaN
# 1             NaN                  NaN                    NaN
# 2       -2.794290             1.000000               0.275976
# 3             NaN                  NaN               0.003076
# 4             NaN                  NaN               0.074905
# ...           ...                  ...                    ...
# 7363          NaN                  NaN                    NaN
# 7364     0.220139             0.593434                    NaN
# 7365    -1.409059             0.561394               0.001103
# 7366    -0.187978             0.512577               0.062551
# 7367    -8.586707             0.261450               0.089683
#
#       Cash/Assets Ratio  Total Debt/Assets ratio  Net Debt/Assets ratio
# 0                   NaN                      NaN                    NaN
# 1                   NaN                 0.113643                    NaN
# 2              0.275053                 0.036456                    NaN
# 3              0.179424                 0.023373                    NaN
# 4              0.178600                 0.091012                    NaN
# ...                 ...                      ...                    ...
# 7363                NaN                      NaN                    NaN
# 7364                NaN                 0.065450                    NaN
# 7365           0.139966                 0.056766                    NaN
# 7366           0.048926                 0.064854                    NaN
# 7367           0.160293                 0.080686                    NaN
#
# [7368 rows x 890 columns]

# %%
#Show metrics for one company. 
ticker_to_show = "GMG.AX"

financial_ratios_to_show = [i[2] for i in financial_ratio_tuples]
roc_to_show = ["Total Revenue", "Gross Profit", "Net Income Common Stockholders", "EBITDA", "EBIT","Interest Expense","Total Debt","Net Debt","Diluted EPS","Basic EPS"]
is_bs_co_df.loc[is_bs_co_df['ticker'] == ticker_to_show, ["ticker","FY_End"]+financial_ratios_to_show + [metric+ " y/y change" for metric in roc_to_show]]
# Out:
#       ticker      FY_End  Total Asset Turnover       ROE       ROA      ROIC  \
# 3026  GMG.AX  2020-06-30                   NaN       NaN       NaN       NaN
# 3027  GMG.AX  2021-06-30                   NaN       NaN       NaN       NaN
# 3028  GMG.AX  2022-06-30              0.106921  0.230782  0.178280  0.198035
# 3029  GMG.AX  2023-06-30              0.085381  0.090561  0.068628  0.076890
# 3030  GMG.AX  2024-06-30              0.080334 -0.005562 -0.004133 -0.004649
#
#       Net Income Margin  Operating Profit Margin  EBITDA Margin  EBIT Margin  \
# 3026                NaN                      NaN            NaN          NaN
# 3027           1.245636                 0.202101       1.326724     1.314332
# 3028           1.667399                 0.407766       1.946911     1.938559
# 3029           0.803782                 0.323131       1.039058     1.030453
# 3030          -0.051451                 0.241650       0.011861     0.002757
#
#       ...  Total Revenue y/y change  Gross Profit y/y change  \
# 3026  ...                       NaN                      NaN
# 3027  ...                       NaN                      NaN
# 3028  ...                  0.103179                 0.518264
# 3029  ...                 -0.052161                -0.107341
# 3030  ...                 -0.009533                 0.048990
#
#       Net Income Common Stockholders y/y change  EBITDA y/y change  \
# 3026                                        NaN                NaN
# 3027                                        NaN                NaN
# 3028                                   0.476707           0.618868
# 3029                                  -0.543087          -0.494142
# 3030                                  -1.063402          -0.988693
#
#       EBIT y/y change  Interest Expense y/y change  Total Debt y/y change  \
# 3026              NaN                          NaN                    NaN
# 3027              NaN                          NaN                    NaN
# 3028         0.627121                    10.912371               0.347445
# 3029        -0.496171                     0.115102               0.157710
# 3030        -0.997350                    -0.758246               0.107838
#
#       Net Debt y/y change  Diluted EPS y/y change  Basic EPS y/y change
# 3026                  NaN                     NaN                   NaN
# 3027                  NaN                     NaN                   NaN
# 3028             0.558207                0.464373              0.460925
# 3029             0.088166               -0.545302             -0.546943
# 3030            -0.016246               -1.063961             -1.062651
#
# [5 rows x 25 columns]

# %%
#Takes in metric of a company and returns metric for the past three years
retrieve_metric_3Y_time_series(is_bs_co_df,"ROA")
# Out:
#         ROA_2022  ROA_2023  ROA_2024
# ticker
# 14D.AX -0.106111 -0.168631 -0.262091
# 1AD.AX -0.615396 -0.527830 -0.808843
# 1AE.AX       NaN -0.970428 -0.719021
# 1AI.AX -0.661666 -0.496735 -0.566012
# 1CG.AX -3.008938 -0.734384       NaN
# ...          ...       ...       ...
# ZLD.AX -0.309997 -0.155688 -1.871771
# ZMI.AX -0.061694 -0.050235 -0.171987
# ZMM.AX -0.527962 -0.759696 -0.734884
# ZNC.AX  0.072992 -0.403893 -0.264940
# ZNO.AX -0.435831 -0.020742 -0.742779
#
# [1605 rows x 3 columns]

# %%
directory_date_metrics_over_time = os.path.join("..", "reports", "AU")

ls_metrics_to_show = ["ROE","EBIT Margin","ROA","ROIC"] 

df_comp = retrieve_metrics_3Y_time_series(is_bs_co_df,ls_metrics_to_show, ticker_list, directory_date_metrics_over_time)
df_comp
# Out:
# Directory '..\reports\AU' already exists.
#       Ticker           sector  ROE_2022  ROE_2023  ROE_2024  EBIT Margin_2022  \
# 1650  PNT.AX  Basic Materials -0.189989 -0.191141       NaN               NaN
# 1082  ESR.AX  Basic Materials -0.135169 -0.076960 -0.139937               NaN
# 853   ETM.AX  Basic Materials -0.221808 -0.264664       NaN               NaN
# 714   EUR.AX  Basic Materials -0.203432 -0.168568 -5.867545       -400.624365
# 1322  EV1.AX  Basic Materials       NaN -1.428663 -1.319292               NaN
# ...      ...              ...       ...       ...       ...               ...
# 880   KPO.AX        Utilities -0.403538 -0.406249 -0.451752               NaN
# 409   LGI.AX        Utilities       NaN  0.150313  0.130615               NaN
# 51    APA.AX        Utilities  0.110989  0.158743  0.426051          0.340835
# 1583  H2G.AX        Utilities -0.462544 -0.451156       NaN         -8.506716
# 1076  14D.AX        Utilities -0.124460 -0.189670 -0.306851         -2.794290
#
#       EBIT Margin_2023  EBIT Margin_2024  ROA_2022  ROA_2023  ROA_2024  \
# 1650               NaN               NaN -0.182756 -0.183304       NaN
# 1082         -3.912145               NaN -0.124565 -0.072181 -0.134626
# 853                NaN               NaN -0.200452 -0.236600       NaN
# 714                NaN               NaN -0.199388 -0.161688 -2.341511
# 1322               NaN               NaN       NaN -1.322864 -1.166976
# ...                ...               ...       ...       ...       ...
# 880                NaN               NaN -1.384394 -1.463851 -6.101089
# 409           0.268491          0.299585       NaN  0.095827  0.087829
# 51            0.335797          0.560066  0.015080  0.016592  0.055209
# 1583        -12.463018               NaN -0.312779 -0.406081       NaN
# 1076               NaN               NaN -0.106111 -0.168631 -0.262091
#
#       ROIC_2022  ROIC_2023  ROIC_2024
# 1650  -0.189989  -0.191141        NaN
# 1082  -0.134073  -0.075080  -0.136600
# 853   -0.221808  -0.264664        NaN
# 714   -0.202833  -0.168568  -5.718612
# 1322        NaN  -1.428663  -1.319292
# ...         ...        ...        ...
# 880   -0.403538  -0.406249  -0.451752
# 409         NaN   0.120847   0.108669
# 51     0.018457   0.020434   0.067365
# 1583  -0.419745  -0.445466        NaN
# 1076  -0.124460  -0.189670  -0.306851
#
# [1606 rows x 14 columns]

# %%
#Option 1
import gradio as gr
import pandas as pd


# roc_to_show = ["Total Revenue","EBITDA"]
# roc_cols = [col for col in merge_is_df.columns if "y/y change" in col.lower()]
financial_ratios_to_show = [i[2] for i in financial_ratio_tuples]
ls_metrics_to_show = financial_ratios_to_show 

def show_dataframe(ticker1, ticker2, metric):
    ls_tickers = []
    ls_tickers.append(ticker1)
    ls_tickers.append(ticker2)

    df = is_bs_co_df[is_bs_co_df["ticker"].isin(ls_tickers)]

    df = retrieve_metric_3Y_time_series(df,metric)
    
    desired_cols = df.columns[:3]

    df = df.merge(ticker_list,left_index=True,right_on="Ticker",how="inner")

    df.sort_values(by="sector",inplace=True)
    df = df[["Ticker", "sector"] + list(desired_cols)]
    
    return gr.update(value = df , visible= True)


def show_industry_metrics_median(metric):
    
    df_ind = is_bs_co_df.groupby(by=["sector","FY"])[metric].median().unstack().reset_index()
    df_ind.rename_axis(None,axis = 1, inplace=True)
    df_ind = df_ind.replace([np.inf, -np.inf], np.nan)
    # col_df = df_ind.columns[:1] + df_ind.columns[-3:]
    # col_df =  df_ind.columns[-3:]
    # df_ind = df_ind[col_df]


    return gr.update(value = df_ind, visible=True)


with gr.Blocks() as demo:
    gr.Markdown("# ASX Stock Screener")
    with gr.Column(scale = 1):
        dropdown1 = gr.Dropdown(choices = list(ticker_list["Ticker"]), value="CBA.AX", label="Select Ticker 1")
        dropdown2 = gr.Dropdown(choices = list(ticker_list["Ticker"]), value="BHP.AX", label="Select Ticker 2")
        dropdown_m1 = gr.Dropdown(choices = ls_metrics_to_show, label="Metric to show 1")
        dropdown_m2 = gr.Dropdown(choices = ls_metrics_to_show, value = "ROA", label="Metric to show 2")
        

    with gr.Column(scale = 1):
        output1 = gr.DataFrame(visible = False, max_height=1000)
        output2 = gr.DataFrame(visible = False, max_height=1000)

    with gr.Column(scale = 1):
        
        dropdown_ind = gr.Dropdown(choices = ls_metrics_to_show, value="ROE", label="Select Metric for Industry")
        output_ind = gr.DataFrame(visible = False, max_height=1000)
        
    
    
    dropdown1.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m1], outputs=output1)
    dropdown1.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m2], outputs=output2)

    dropdown2.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m1], outputs=output1)
    dropdown2.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m1], outputs=output2)

    dropdown_m1.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m1], outputs=output1)
    dropdown_m2.change(show_dataframe, inputs=[dropdown1, dropdown2,dropdown_m2], outputs=output2)

    dropdown_ind.change(show_industry_metrics_median, inputs=[dropdown_ind], outputs=output_ind)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def get_metric_industry_median(df, metric:str):
    df = df.groupby(by=["sector","FY"])[metric].median().unstack().reset_index()
    df.rename_axis(None,axis = 1, inplace=True)
    df = df.replace([np.inf, -np.inf], np.nan)
    # df = df.iloc[:,-3:]
    return df

get_metric_industry_median(is_bs_co_df,"ROE")
# Out:
#                     sector  2020      2021      2022      2023      2024
# 0          Basic Materials   NaN -0.147033 -0.158312 -0.184986 -0.204501
# 1   Communication Services   NaN -0.028903 -0.044114 -0.051473 -0.009390
# 2        Consumer Cyclical   NaN  0.203851  0.116939  0.075723  0.108387
# 3       Consumer Defensive   NaN -0.290304 -0.031299 -0.045992 -0.016830
# 4                   Energy   NaN -0.143559 -0.094468 -0.109621 -0.087443
# 5                Financial   NaN  0.207565  0.080652  0.077339  0.084214
# 6       Financial Services   NaN  0.119039  0.055478  0.070106  0.074190
# 7               Healthcare   NaN -0.555320 -0.375671 -0.375877 -0.389483
# 8              Industrials   NaN -0.586473  0.056908  0.062976  0.072149
# 9                      N.A   NaN       NaN -1.220066 -0.815600 -0.239062
# 10             Real Estate   NaN  0.050726  0.128956  0.020553  0.019380
# 11              Technology   NaN -0.981673 -0.311331 -0.293387 -0.162023
# 12               Utilities   NaN  0.058876 -0.091260 -0.075778 -0.122171
